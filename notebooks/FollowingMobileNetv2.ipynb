# %% [markdown]
# # 🔮 Importaciones necesarias para el proyecto

# %%
import os
import cv2
import time
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Imprime la versión de OpenCV
print(f"Versión de OpenCV: {cv2.__version__}")  
# Imprime la versión de Numpy
print(f"Versión de Numpy: {np.__version__}")   
# Imprime la versión de Pandas
print(f"Versión de Pandas: {pd.__version__}")   
# Imprime la versión de TensorFlow
print(f"Versión de TensorFlow: {tf.__version__}")  
# Imprime la versión de Sklearn
print(f"Version de Sklearn: {sk.__version__}")    
# Imprime la versión de Matplotlib
print(f"Versión de Matplotlib.pyplot: {mpl.__version__}")
# Out:
# Versión de OpenCV: 4.8.1
# Versión de Numpy: 1.21.5
# Versión de Pandas: 1.3.5
# Versión de TensorFlow: 2.1.0
# Version de Sklearn: 1.0.2
# Versión de Matplotlib.pyplot: 3.5.3

# %%
# Obtiene el nombre del dispositivo GPU
device_name = tf.test.gpu_device_name()

# Comprueba si el nombre del dispositivo no es '/device:GPU:0'
if device_name != '/device:GPU:0':
    # Genera un error del sistema si no se encuentra un dispositivo GPU
    raise SystemError('GPU device not found')

# Imprime el mensaje indicando que se encontró una GPU y muestra el nombre del dispositivo
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## 📂 Configuraciones del path para lectura

# %%
# Cambia el directorio de trabajo actual al directorio padre
os.chdir("..")  
# Imprime el directorio de trabajo actual después del cambio
print(os.getcwd())
# Out:
# c:\Users\USER\Desktop\PDI\Traffic-Sign-Classifier

# %%
# Obtenemos la dirección actual del path donde se está ejecutando el Jupyter Notebook
cwd = os.getcwd()

# Nos movemos a la carpeta donde se encuentran las imágenes a testear
os.chdir(f"{cwd}/classifier_resized_VGG16/")

# Imprime el directorio de trabajo actual después del cambio
print(os.getcwd())  

# Guardamos la dirección actual en la variable "principal_directory" para su posterior uso
principal_directory = os.getcwd()
# Out:
# c:\Users\USER\Desktop\PDI\Traffic-Sign-Classifier\classifier_resized_MobileNetV2

# %%
# Listamos los archivos de la ruta
print(os.listdir())
# Out:
# ['speeds', 'stops', 'trafficLights']

# %% [markdown]
# # 🧐 Lectura de imágenes

# %%
# Inicializamos listas para almacenar imágenes y etiquetas
images = []  # Lista de imágenes
labels = []  # Lista de etiquetas

i = 0  # Inicializamos una variable para llevar el seguimiento de las etiquetas

# Iteramos sobre las carpetas dentro del directorio principal
for folder in os.listdir(principal_directory):
    folder_path = os.path.join(principal_directory, folder)
    
    # Verificamos si el elemento en el directorio es una carpeta
    if os.path.isdir(folder_path):
        
        # Etiqueta de la carpeta, que corresponde a la clase
        label = i
        
        # Iteramos sobre los archivos dentro de la carpeta
        for file in os.listdir(folder_path):
            archivo_path = os.path.join(folder_path, file)
            
            # Leemos la imagen con OpenCV y la agregamos a la lista de imágenes
            image = cv2.imread(archivo_path)
            
            # Convertimos la imagen al espacio de color RGB desde BGR (formato por defecto de OpenCV)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            # Normalizamos los valores de la imagen de 0 a 1
            normalized_img = image / 255.0
            images.append(normalized_img)
            labels.append(label)
            
    i += 1  # Incrementamos la etiqueta para la próxima clase
            
# Creamos un DataFrame a partir de las listas de imágenes y etiquetas
data = {'Images': images, 'Labels': labels}
df = pd.DataFrame(data)            
            
# Selecciona un índice aleatorio dentro del rango de las imágenes
index = np.random.randint(0, len(images))

# Imprime los valores de píxeles de una ubicación específica (5, 5) en la imagen antes de la normalización
print("Pixeles de la imagen antes de la normalización: ", images[index][5][5] * 255)
# Imprime los valores de píxeles de la misma ubicación (5, 5) en la imagen después de la normalización
print("Pixeles de la imagen después de la normalización: ", images[index][5][5])

print("-------------------------------------------------------------------------------")

# Imprime la cantidad total de imágenes en la lista
print("Cantidad de imágenes: ", len(images))
# Imprime la cantidad total de etiquetas en la lista
print("Cantidad de etiquetas: ", len(labels))
# Out:
# Pixeles de la imagen antes de la normalización:  [222. 227. 231.]
# Pixeles de la imagen después de la normalización:  [0.87058824 0.89019608 0.90588235]
# -------------------------------------------------------------------------------
# Cantidad de imágenes:  600
# Cantidad de etiquetas:  600

# %%
# Cambia al directorio padre
os.chdir("..")  
# Nos movemos a la carpeta 'classifier' dentro del directorio padre
os.chdir(f"{cwd}/classifier/")
# Imprime el directorio de trabajo actual después de los cambios 
print(os.getcwd())
# Out:
# c:\Users\USER\Desktop\PDI\Traffic-Sign-Classifier\classifier

# %%
# Inicializa la figura con un tamaño específico
plt.figure(figsize=(10, 15))

# Selecciona un índice aleatorio para la categoría "Speed" dentro del rango 0-199
indexSpeed = np.random.randint(0, 199)

# Crea el primer subplot para mostrar una imagen de la categoría "Speed"
plt.subplot(3, 2, 1), plt.imshow(images[indexSpeed])
plt.gca().set_title('Speed Image')  # Establece el título del subplot
plt.xticks([]), plt.yticks([])  # Oculta las marcas en los ejes

# Lee y muestra otra imagen de la categoría "Speed" desde una ubicación específica
image_speed = cv2.cvtColor(cv2.imread(f"speeds/Velocidad-{indexSpeed + 1}.jpg"), cv2.COLOR_BGR2RGB)
plt.subplot(3, 2, 2), plt.imshow(image_speed)
plt.gca().set_title('Speed Image')
plt.xticks([]), plt.yticks([])

# Selecciona un índice aleatorio para la categoría "Stop" dentro del rango 199-398
indexStop = np.random.randint(199, 399)

# Crea el subplot para mostrar una imagen de la categoría "Stop"
plt.subplot(3, 2, 3), plt.imshow(images[indexStop])
plt.gca().set_title('Stop Image')
plt.xticks([]), plt.yticks([])

# Lee y muestra otra imagen de la categoría "Stop" desde una ubicación específica
image_stop = cv2.cvtColor(cv2.imread(f"stops/Pare-{indexStop - 200}.jpg"), cv2.COLOR_BGR2RGB)
plt.subplot(3, 2, 4), plt.imshow(image_stop)
plt.gca().set_title('Stop Image')
plt.xticks([]), plt.yticks([])

# Selecciona un índice aleatorio para la categoría "Traffic Light" dentro del rango 400-558
indexTrafficLight = np.random.randint(400, 559)

# Crea el subplot para mostrar una imagen de la categoría "Traffic Light"
plt.subplot(3, 2, 5), plt.imshow(images[indexTrafficLight])
plt.gca().set_title('Traffic Light Image')
plt.xticks([]), plt.yticks([])

# Lee y muestra otra imagen de la categoría "Traffic Light" desde una ubicación específica
image_trafficlight = cv2.cvtColor(cv2.imread(f"trafficLights/Semaforo-{indexTrafficLight - 400}.jpg"), cv2.COLOR_BGR2RGB)
plt.subplot(3, 2, 6), plt.imshow(image_trafficlight)
plt.gca().set_title('Traffic Light Image')
plt.xticks([]), plt.yticks([])

# Ajusta el diseño de los subplots para una visualización más ordenada
plt.tight_layout()

# Muestra la figura con los subplots
plt.show()

# %%
# Muestra todas las filas del DataFrame 'df' excepto la última
df.head()
# Out:
#                                               Images  Labels
# 0  [[[0.7411764705882353, 0.7764705882352941, 0.8...       0
# 1  [[[0.7098039215686275, 0.7294117647058823, 0.7...       0
# 2  [[[0.11764705882352941, 0.34901960784313724, 0...       0
# 3  [[[0.5215686274509804, 0.5568627450980392, 0.5...       0
# 4  [[[0.11764705882352941, 0.3607843137254902, 0....       0

# %% [markdown]
# ### Data Augmentation

# %%
# Convierte la lista de imágenes en un arreglo NumPy
x = np.array(df.Images.tolist())
# Convierte la lista de etiquetas en un arreglo NumPy
y = np.array(df.Labels.tolist())
# Reorganiza la matriz de etiquetas para que tenga la forma adecuada (número de ejemplos, 1)
y = y.reshape((y.shape[0], -1))

# %%
# Definimos las transformaciones para el aumento de datos utilizando ImageDataGenerator
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=10,          # Rango de rotación en grados
    zoom_range=0.2,            # Rango de zoom
    horizontal_flip=True,      # Volteo horizontal aleatorio
    vertical_flip=True,        # Volteo vertical aleatorio
    fill_mode='constant'       # Modo de llenado para píxeles fuera de los límites de la imagen original
)

# %%
# Crea un generador de datos de entrenamiento utilizando train_datagen
train_gen = train_datagen.flow(
    x=x,          # Datos de entrada (imágenes)
    y=y,          # Etiquetas correspondientes a las imágenes
    batch_size=32 # Tamaño del lote (batch size) para generar lotes de datos
)

# %%
# Divide el conjunto de datos en conjuntos de entrenamiento y prueba, con un 20% para prueba
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=50, stratify=y)

# Número de clases en el problema (en este caso, 3 clases)
num_classes = 3

# Convierte las etiquetas de entrenamiento y prueba en codificación one-hot
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# Imprime las dimensiones de los conjuntos de datos
print(f"X_Train: {x_train.shape}")  # Dimensiones del conjunto de entrenamiento de características
print(f"X_Test: {x_test.shape}")    # Dimensiones del conjunto de prueba de características
print(f"Y_Train: {y_train.shape}")  # Dimensiones del conjunto de entrenamiento de etiquetas
print(f"Y_Test: {y_test.shape}")    # Dimensiones del conjunto de prueba de etiquetas
# Out:
# X_Train: (480, 224, 224, 3)
# X_Test: (120, 224, 224, 3)
# Y_Train: (480, 3)
# Y_Test: (120, 3)

# %% [markdown]
# ## Build the model

# %% [markdown]
# ### Model taked from: [Kaggle](https://www.kaggle.com/code/yacharki/traffic-signs-image-classification-96-cnn)

# %%
def VGG16(input_shape=(224, 224, 3), num_classes=1000):
    model = Sequential([
        # Block 1
        Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=input_shape),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Block 2
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Block 3
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Block 4
        Conv2D(512, (3, 3), activation='relu', padding='same'),
        Conv2D(512, (3, 3), activation='relu', padding='same'),
        Conv2D(512, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Block 5
        Conv2D(512, (3, 3), activation='relu', padding='same'),
        Conv2D(512, (3, 3), activation='relu', padding='same'),
        Conv2D(512, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Classification block
        Flatten(),
        Dense(516, activation='relu'),
        Dense(516, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam',
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])
    return model

# Create the VGG16 model
model = VGG16()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 516)               12945924
# _________________________________________________________________
# dense_4 (Dense)              (None, 516)               266772
# _________________________________________________________________
# dense_5 (Dense)              (None, 1000)              517000
# =================================================================
# Total params: 28,444,384
# Trainable params: 28,444,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Subimos un nivel en el explorador de archivos
os.chdir("..")  # Cambia al directorio padre
os.chdir(f"{cwd}/models/")  # Nos movemos a la carpeta 'models' dentro del directorio padre
model_directory = os.getcwd()  # Guardamos la dirección actual en la variable 'model_directory'
print(os.getcwd())  # Imprime el directorio de trabajo actual después de los cambios

# Listamos los archivos en la ruta actual
print(os.listdir())
# Out:
# c:\Users\USER\Desktop\PDI\Traffic-Sign-Classifier\models
# ['best_modelV1.h5', 'ModelV1.h5']

# %%
# Callback ModelCheckpoint para guardar el modelo con la mejor precisión en entrenamiento
checkpoint = ModelCheckpoint(
    filepath='ModelV2_VGG16.h5',  # Nombre del archivo donde se guardará el modelo
    monitor='accuracy',  # Métrica que se supervisará (precisión en entrenamiento)
    mode='max',  # Modo 'max' para guardar el mejor modelo basado en la métrica
    save_best_only=True  # Guarda solo el mejor modelo
    # save_weights_only=True  # Opcional: guardar solo los pesos del modelo en lugar de todo el modelo
)

# Callback EarlyStopping para detener el entrenamiento si la precisión en validación no mejora
stopping = EarlyStopping(
    monitor='val_accuracy',  # Métrica que se supervisará (precisión en validación)
    patience=50,  # Número de épocas sin mejora antes de detener el entrenamiento
    mode='max',  # Modo 'max' para detener el entrenamiento si la métrica aumenta
    restore_best_weights=True  # Restaura los mejores pesos del modelo cuando se detiene el entrenamiento
)

# %%
# Iniciamos el tiempo de entrenamiento
start = time.time()

# Utilizamos la GPU con '/GPU:0' para entrenar el modelo
with tf.device('/GPU:0'):
    # Entrenamos el modelo utilizando los datos de entrenamiento y validación, con un total de 400 épocas
    history = model.fit(x_train, y_train, epochs=400, validation_data=(x_test, y_test), callbacks=[checkpoint, stopping])

# Finalizamos el tiempo de entrenamiento
finish = time.time()

# Imprimimos el tiempo que tomó el entrenamiento
print(f"Se demoró: {finish - start} segundos.")
# Out:
# Train on 480 samples, validate on 120 samples
# Epoch 1/400
# 480/480 [==============================] - 1s 3ms/sample - loss: 18.4100 - accuracy: 0.3125 - val_loss: 7.7989 - val_accuracy: 0.3333
# Epoch 2/400
# 480/480 [==============================] - 1s 1ms/sample - loss: 4.4449 - accuracy: 0.3250 - val_loss: 2.4028 - val_accuracy: 0.3333
# Epoch 3/400
# 480/480 [==============================] - 0s 1ms/sample - loss: 2.0269 - accuracy: 0.3313 - val_loss: 1.7952 - val_accuracy: 0.3333
# Epoch 4/400
# 480/480 [==============================] - 1s 1ms/sample - loss: 1.6711 - accuracy: 0.3833 - val_loss: 1.5353 - val_accuracy: 0.5333
# Epoch 5/400
# 480/480 [==============================] - 0s 972us/sample - loss: 1.4018 - accuracy: 0.4729 - val_loss: 1.3905 - val_accuracy: 0.5250
# Epoch 6/400
# 480/480 [==============================] - 0s 975us/sample - loss: 1.2486 - accuracy: 0.5146 - val_loss: 1.2433 - val_accuracy: 0.5583
# Epoch 7/400
# 480/480 [==============================] - 0s 1ms/sample - loss: 1.1982 - accuracy: 0.5250 - val_loss: 1.1996 - val_accuracy: 0.5667
# Epoch 8/400
# 480/480 [==============================] - 0s 989us/sample - loss: 1.1763 - accuracy: 0.5562 - val_loss: 1.2295 - val_accuracy: 0.5833
# Epoch 9/400
# 480/480 [==============================] - 1s 1ms/sample - loss: 1.1579 - accuracy: 0.5625 - val_loss: 1.1351 - val_accuracy: 0.5833
# Epoch 10/400
# 480/480 [==============================] - 0s 993us/sample - loss: 1.0811 - accuracy: 0.5708 - val_loss: 1.1283 - val_accuracy: 0.5500
# Epoch 11/400
# 480/480 [==============================] - 0s 932us/sample - loss: 1.1297 - accuracy: 0.5250 - val_loss: 1.1624 - val_accuracy: 0.5500
# Epoch 12/400
# 480/480 [==============================] - 0s 991us/sample - loss: 1.0595 - accuracy: 0.5833 - val_loss: 1.1892 - val_accuracy: 0.5667
# Epoch 13/400
# 480/480 [==============================] - 0s 929us/sample - loss: 1.0502 - accuracy: 0.5688 - val_loss: 1.1706 - val_accuracy: 0.6167
# Epoch 14/400
# 480/480 [==============================] - 0s 871us/sample - loss: 1.0296 - accuracy: 0.5500 - val_loss: 1.0402 - val_accuracy: 0.5667
# Epoch 15/400
# 480/480 [==============================] - 0s 938us/sample - loss: 1.0134 - accuracy: 0.5750 - val_loss: 1.1075 - val_accuracy: 0.5667
# Epoch 16/400
# 480/480 [==============================] - 0s 870us/sample - loss: 1.0069 - accuracy: 0.5813 - val_loss: 1.0452 - val_accuracy: 0.5750
# Epoch 17/400
# 480/480 [==============================] - 0s 985us/sample - loss: 0.9870 - accuracy: 0.6125 - val_loss: 1.0574 - val_accuracy: 0.5667
# Epoch 18/400
# 480/480 [==============================] - 0s 887us/sample - loss: 0.9840 - accuracy: 0.6042 - val_loss: 1.0120 - val_accuracy: 0.5917
# Epoch 19/400
# 480/480 [==============================] - 0s 884us/sample - loss: 0.9228 - accuracy: 0.5792 - val_loss: 1.0403 - val_accuracy: 0.5500
# Epoch 20/400
# 480/480 [==============================] - 0s 949us/sample - loss: 0.9871 - accuracy: 0.5792 - val_loss: 1.0689 - val_accuracy: 0.5500
# Epoch 21/400
# 480/480 [==============================] - 0s 921us/sample - loss: 1.0494 - accuracy: 0.5583 - val_loss: 1.1451 - val_accuracy: 0.5417
# Epoch 22/400
# 480/480 [==============================] - 0s 904us/sample - loss: 0.9995 - accuracy: 0.5729 - val_loss: 1.0794 - val_accuracy: 0.5583
# Epoch 23/400
# 480/480 [==============================] - 0s 958us/sample - loss: 0.9560 - accuracy: 0.5542 - val_loss: 1.0296 - val_accuracy: 0.5833
# Epoch 24/400
# 480/480 [==============================] - 0s 985us/sample - loss: 0.9439 - accuracy: 0.5625 - val_loss: 1.0041 - val_accuracy: 0.5750
# Epoch 25/400
# 480/480 [==============================] - 0s 913us/sample - loss: 0.9377 - accuracy: 0.6104 - val_loss: 0.9862 - val_accuracy: 0.5750
# Epoch 26/400
# 480/480 [==============================] - 0s 940us/sample - loss: 0.8982 - accuracy: 0.5875 - val_loss: 0.9679 - val_accuracy: 0.5750
# Epoch 27/400
# 480/480 [==============================] - 0s 918us/sample - loss: 0.9433 - accuracy: 0.5833 - val_loss: 0.9958 - val_accuracy: 0.6000
# Epoch 28/400
# 480/480 [==============================] - 0s 896us/sample - loss: 0.9394 - accuracy: 0.6125 - val_loss: 1.2187 - val_accuracy: 0.5333
# Epoch 29/400
# 480/480 [==============================] - 0s 938us/sample - loss: 0.9594 - accuracy: 0.5708 - val_loss: 0.9852 - val_accuracy: 0.5750
# Epoch 30/400
# 480/480 [==============================] - 0s 982us/sample - loss: 0.9126 - accuracy: 0.6333 - val_loss: 0.9342 - val_accuracy: 0.5667
# Epoch 31/400
# 480/480 [==============================] - 0s 957us/sample - loss: 0.9007 - accuracy: 0.6146 - val_loss: 0.9651 - val_accuracy: 0.5750
# Epoch 32/400
# 480/480 [==============================] - 0s 895us/sample - loss: 0.8908 - accuracy: 0.6062 - val_loss: 0.9202 - val_accuracy: 0.6167
# Epoch 33/400
# 480/480 [==============================] - 0s 901us/sample - loss: 0.8726 - accuracy: 0.6250 - val_loss: 0.9206 - val_accuracy: 0.6250
# Epoch 34/400
# 480/480 [==============================] - 0s 835us/sample - loss: 0.8759 - accuracy: 0.6062 - val_loss: 0.9780 - val_accuracy: 0.5667
# Epoch 35/400
# 480/480 [==============================] - 0s 870us/sample - loss: 0.9047 - accuracy: 0.5646 - val_loss: 1.0111 - val_accuracy: 0.5417
# Epoch 36/400
# 480/480 [==============================] - 0s 864us/sample - loss: 0.8937 - accuracy: 0.5813 - val_loss: 0.9378 - val_accuracy: 0.5833
# Epoch 37/400
# 480/480 [==============================] - 0s 905us/sample - loss: 0.9139 - accuracy: 0.6042 - val_loss: 0.9397 - val_accuracy: 0.6250
# Epoch 38/400
# 480/480 [==============================] - 0s 964us/sample - loss: 0.8710 - accuracy: 0.6562 - val_loss: 0.9609 - val_accuracy: 0.5917
# Epoch 39/400
# 480/480 [==============================] - 0s 843us/sample - loss: 0.9124 - accuracy: 0.5958 - val_loss: 0.9035 - val_accuracy: 0.5833
# Epoch 40/400
# 480/480 [==============================] - 0s 877us/sample - loss: 0.9527 - accuracy: 0.5750 - val_loss: 1.0266 - val_accuracy: 0.6167
# Epoch 41/400
# 480/480 [==============================] - 0s 882us/sample - loss: 0.8704 - accuracy: 0.6187 - val_loss: 0.9581 - val_accuracy: 0.5667
# Epoch 42/400
# 480/480 [==============================] - 0s 866us/sample - loss: 0.8570 - accuracy: 0.6375 - val_loss: 0.8875 - val_accuracy: 0.6250
# Epoch 43/400
# 480/480 [==============================] - 0s 862us/sample - loss: 0.8754 - accuracy: 0.6125 - val_loss: 0.8752 - val_accuracy: 0.6583
# Epoch 44/400
# 480/480 [==============================] - 0s 888us/sample - loss: 0.8480 - accuracy: 0.6479 - val_loss: 0.9454 - val_accuracy: 0.6000
# Epoch 45/400
# 480/480 [==============================] - 0s 870us/sample - loss: 0.8806 - accuracy: 0.6208 - val_loss: 0.9236 - val_accuracy: 0.5750
# Epoch 46/400
# 480/480 [==============================] - 0s 906us/sample - loss: 0.9624 - accuracy: 0.5938 - val_loss: 1.0089 - val_accuracy: 0.5583
# Epoch 47/400
# 480/480 [==============================] - 0s 942us/sample - loss: 0.8809 - accuracy: 0.5813 - val_loss: 1.0979 - val_accuracy: 0.5917
# Epoch 48/400
# 480/480 [==============================] - 0s 947us/sample - loss: 0.8955 - accuracy: 0.5750 - val_loss: 0.9111 - val_accuracy: 0.6333
# Epoch 49/400
# 480/480 [==============================] - 0s 982us/sample - loss: 0.8562 - accuracy: 0.6042 - val_loss: 0.9144 - val_accuracy: 0.6250
# Epoch 50/400
# 480/480 [==============================] - 0s 923us/sample - loss: 0.7978 - accuracy: 0.6521 - val_loss: 0.8871 - val_accuracy: 0.5917
# Epoch 51/400
# 480/480 [==============================] - 0s 886us/sample - loss: 0.8553 - accuracy: 0.6229 - val_loss: 0.9181 - val_accuracy: 0.6750
# Epoch 52/400
# 480/480 [==============================] - 0s 882us/sample - loss: 0.8397 - accuracy: 0.6562 - val_loss: 0.9350 - val_accuracy: 0.6917
# Epoch 53/400
# 480/480 [==============================] - 0s 897us/sample - loss: 0.8603 - accuracy: 0.6438 - val_loss: 0.9093 - val_accuracy: 0.6333
# Epoch 54/400
# 480/480 [==============================] - 0s 948us/sample - loss: 0.8352 - accuracy: 0.6187 - val_loss: 0.8708 - val_accuracy: 0.7000
# Epoch 55/400
# 480/480 [==============================] - 0s 944us/sample - loss: 0.8139 - accuracy: 0.6562 - val_loss: 0.8317 - val_accuracy: 0.6833
# Epoch 56/400
# 480/480 [==============================] - 0s 987us/sample - loss: 0.7893 - accuracy: 0.6708 - val_loss: 0.9311 - val_accuracy: 0.6000
# Epoch 57/400
# 480/480 [==============================] - 0s 961us/sample - loss: 0.8850 - accuracy: 0.6333 - val_loss: 1.0530 - val_accuracy: 0.6250
# Epoch 58/400
# 480/480 [==============================] - 0s 1ms/sample - loss: 0.8837 - accuracy: 0.6438 - val_loss: 1.1469 - val_accuracy: 0.5917
# Epoch 59/400
# 480/480 [==============================] - 0s 1ms/sample - loss: 0.8908 - accuracy: 0.6021 - val_loss: 1.0265 - val_accuracy: 0.6083
# Epoch 60/400
# 480/480 [==============================] - 0s 994us/sample - loss: 0.8852 - accuracy: 0.6104 - val_loss: 0.8899 - val_accuracy: 0.5917
# Epoch 61/400
# 480/480 [==============================] - 0s 976us/sample - loss: 0.8220 - accuracy: 0.6375 - val_loss: 0.8709 - val_accuracy: 0.6833
# Epoch 62/400
# 480/480 [==============================] - 1s 1ms/sample - loss: 0.8330 - accuracy: 0.6375 - val_loss: 0.8849 - val_accuracy: 0.6167
# Epoch 63/400
# 480/480 [==============================] - 1s 1ms/sample - loss: 0.8082 - accuracy: 0.6875 - val_loss: 0.8494 - val_accuracy: 0.6917
# Epoch 64/400
# 480/480 [==============================] - 0s 881us/sample - loss: 0.8041 - accuracy: 0.6875 - val_loss: 0.8851 - val_accuracy: 0.6667
# Epoch 65/400
# 480/480 [==============================] - 0s 982us/sample - loss: 0.8064 - accuracy: 0.6896 - val_loss: 0.8892 - val_accuracy: 0.6833
# Epoch 66/400
# 480/480 [==============================] - 0s 904us/sample - loss: 0.8261 - accuracy: 0.6500 - val_loss: 0.8729 - val_accuracy: 0.6417
# Epoch 67/400
# 480/480 [==============================] - 0s 909us/sample - loss: 0.8145 - accuracy: 0.6896 - val_loss: 0.8268 - val_accuracy: 0.7333
# Epoch 68/400
# 480/480 [==============================] - 0s 833us/sample - loss: 0.7990 - accuracy: 0.6896 - val_loss: 0.9564 - val_accuracy: 0.6167
# Epoch 69/400
# 480/480 [==============================] - 0s 838us/sample - loss: 0.8568 - accuracy: 0.6604 - val_loss: 0.9017 - val_accuracy: 0.7167
# Epoch 70/400
# 480/480 [==============================] - 0s 890us/sample - loss: 0.8119 - accuracy: 0.6708 - val_loss: 0.9260 - val_accuracy: 0.6500
# Epoch 71/400
# 480/480 [==============================] - 0s 878us/sample - loss: 0.7948 - accuracy: 0.6708 - val_loss: 0.8561 - val_accuracy: 0.6833
# Epoch 72/400
# 480/480 [==============================] - 0s 879us/sample - loss: 0.8599 - accuracy: 0.6500 - val_loss: 1.0529 - val_accuracy: 0.6917
# Epoch 73/400
# 480/480 [==============================] - 0s 862us/sample - loss: 0.8430 - accuracy: 0.6521 - val_loss: 0.8895 - val_accuracy: 0.7083
# Epoch 74/400
# 480/480 [==============================] - 0s 907us/sample - loss: 0.8788 - accuracy: 0.6854 - val_loss: 0.9128 - val_accuracy: 0.7000
# Epoch 75/400
# 480/480 [==============================] - 0s 962us/sample - loss: 0.8908 - accuracy: 0.7042 - val_loss: 0.9558 - val_accuracy: 0.5917
# Epoch 76/400
# 480/480 [==============================] - 0s 894us/sample - loss: 0.8793 - accuracy: 0.6479 - val_loss: 0.9508 - val_accuracy: 0.6000
# Epoch 77/400
# 480/480 [==============================] - 0s 889us/sample - loss: 0.8315 - accuracy: 0.6604 - val_loss: 0.8616 - val_accuracy: 0.7167
# Epoch 78/400
# 480/480 [==============================] - 1s 1ms/sample - loss: 0.8002 - accuracy: 0.6979 - val_loss: 0.8664 - val_accuracy: 0.6917
# Epoch 79/400
# 480/480 [==============================] - 0s 993us/sample - loss: 0.8048 - accuracy: 0.7042 - val_loss: 0.8377 - val_accuracy: 0.7500
# Epoch 80/400
# 480/480 [==============================] - 1s 1ms/sample - loss: 0.7969 - accuracy: 0.7229 - val_loss: 0.8450 - val_accuracy: 0.6667
# Epoch 81/400
# 480/480 [==============================] - 0s 874us/sample - loss: 0.7734 - accuracy: 0.7229 - val_loss: 0.8801 - val_accuracy: 0.7083
# Epoch 82/400
# 480/480 [==============================] - 0s 925us/sample - loss: 0.7860 - accuracy: 0.7167 - val_loss: 0.8463 - val_accuracy: 0.7167
# Epoch 83/400
# 480/480 [==============================] - 0s 962us/sample - loss: 0.7808 - accuracy: 0.7250 - val_loss: 0.8389 - val_accuracy: 0.6833
# Epoch 84/400
# 480/480 [==============================] - 1s 1ms/sample - loss: 0.7615 - accuracy: 0.7354 - val_loss: 0.8907 - val_accuracy: 0.7250
# Epoch 85/400
# 480/480 [==============================] - 0s 906us/sample - loss: 0.7893 - accuracy: 0.7146 - val_loss: 0.8542 - val_accuracy: 0.6833
# Epoch 86/400
# 480/480 [==============================] - 0s 958us/sample - loss: 0.7732 - accuracy: 0.7500 - val_loss: 0.9292 - val_accuracy: 0.6417
# Epoch 87/400
# 480/480 [==============================] - 0s 859us/sample - loss: 0.7703 - accuracy: 0.7292 - val_loss: 0.8367 - val_accuracy: 0.7417
# Epoch 88/400
# 480/480 [==============================] - 0s 871us/sample - loss: 0.8127 - accuracy: 0.7271 - val_loss: 0.9132 - val_accuracy: 0.6917
# Epoch 89/400
# 480/480 [==============================] - 0s 883us/sample - loss: 0.8717 - accuracy: 0.6729 - val_loss: 0.8986 - val_accuracy: 0.6667
# Epoch 90/400
# 480/480 [==============================] - 0s 900us/sample - loss: 0.8467 - accuracy: 0.6896 - val_loss: 0.8823 - val_accuracy: 0.6917
# Epoch 91/400
# 480/480 [==============================] - 0s 866us/sample - loss: 0.8636 - accuracy: 0.7104 - val_loss: 0.8555 - val_accuracy: 0.7083
# Epoch 92/400
# 480/480 [==============================] - 0s 895us/sample - loss: 0.8718 - accuracy: 0.7083 - val_loss: 0.8878 - val_accuracy: 0.7167
# Epoch 93/400
# 480/480 [==============================] - 0s 861us/sample - loss: 0.7887 - accuracy: 0.7250 - val_loss: 0.8836 - val_accuracy: 0.6500
# Epoch 94/400
# 480/480 [==============================] - 0s 959us/sample - loss: 0.7919 - accuracy: 0.7125 - val_loss: 0.8901 - val_accuracy: 0.6500
# Epoch 95/400
# 480/480 [==============================] - 0s 875us/sample - loss: 0.7444 - accuracy: 0.7437 - val_loss: 0.7930 - val_accuracy: 0.7333
# Epoch 96/400
# 480/480 [==============================] - 0s 918us/sample - loss: 0.7402 - accuracy: 0.7479 - val_loss: 0.8127 - val_accuracy: 0.7167
# Epoch 97/400
# 480/480 [==============================] - 0s 904us/sample - loss: 0.8475 - accuracy: 0.7042 - val_loss: 0.9362 - val_accuracy: 0.6750
# Epoch 98/400
# 480/480 [==============================] - 0s 901us/sample - loss: 0.8794 - accuracy: 0.6812 - val_loss: 0.9245 - val_accuracy: 0.6917
# Epoch 99/400
# 480/480 [==============================] - 0s 885us/sample - loss: 0.9020 - accuracy: 0.6812 - val_loss: 1.0355 - val_accuracy: 0.6167
# Epoch 100/400
# 480/480 [==============================] - 0s 833us/sample - loss: 0.8555 - accuracy: 0.6687 - val_loss: 0.9258 - val_accuracy: 0.6667
# Epoch 101/400
# 480/480 [==============================] - 0s 919us/sample - loss: 0.7722 - accuracy: 0.7312 - val_loss: 0.8367 - val_accuracy: 0.7000
# Epoch 102/400
# 480/480 [==============================] - 0s 990us/sample - loss: 0.7431 - accuracy: 0.7542 - val_loss: 0.8692 - val_accuracy: 0.6750
# Epoch 103/400
# 480/480 [==============================] - 0s 905us/sample - loss: 0.7705 - accuracy: 0.7250 - val_loss: 0.8612 - val_accuracy: 0.6917
# Epoch 104/400
# 480/480 [==============================] - 0s 843us/sample - loss: 0.7853 - accuracy: 0.7188 - val_loss: 0.8493 - val_accuracy: 0.6917
# Epoch 105/400
# 480/480 [==============================] - 0s 835us/sample - loss: 0.7457 - accuracy: 0.7250 - val_loss: 0.8318 - val_accuracy: 0.6583
# Epoch 106/400
# 480/480 [==============================] - 0s 930us/sample - loss: 0.7409 - accuracy: 0.7646 - val_loss: 0.9657 - val_accuracy: 0.6417
# Epoch 107/400
# 480/480 [==============================] - 0s 871us/sample - loss: 0.8996 - accuracy: 0.6646 - val_loss: 1.0297 - val_accuracy: 0.6833
# Epoch 108/400
# 480/480 [==============================] - 0s 886us/sample - loss: 0.8194 - accuracy: 0.7271 - val_loss: 0.9349 - val_accuracy: 0.6667
# Epoch 109/400
# 480/480 [==============================] - 0s 865us/sample - loss: 0.7968 - accuracy: 0.7458 - val_loss: 0.8476 - val_accuracy: 0.6583
# Epoch 110/400
# 480/480 [==============================] - 0s 856us/sample - loss: 0.7167 - accuracy: 0.7563 - val_loss: 0.8037 - val_accuracy: 0.6917
# Epoch 111/400
# 480/480 [==============================] - 0s 847us/sample - loss: 0.7445 - accuracy: 0.7479 - val_loss: 0.8313 - val_accuracy: 0.7083
# Epoch 112/400
# 480/480 [==============================] - 0s 871us/sample - loss: 0.7503 - accuracy: 0.7542 - val_loss: 0.8386 - val_accuracy: 0.7083
# Epoch 113/400
# 480/480 [==============================] - 0s 976us/sample - loss: 0.7328 - accuracy: 0.7667 - val_loss: 0.8287 - val_accuracy: 0.6917
# Epoch 114/400
# 480/480 [==============================] - 0s 903us/sample - loss: 0.7638 - accuracy: 0.7458 - val_loss: 0.8738 - val_accuracy: 0.6750
# Epoch 115/400
# 480/480 [==============================] - 0s 861us/sample - loss: 0.7512 - accuracy: 0.7479 - val_loss: 0.8724 - val_accuracy: 0.6917
# Epoch 116/400
# 480/480 [==============================] - 0s 836us/sample - loss: 0.7915 - accuracy: 0.7188 - val_loss: 0.9038 - val_accuracy: 0.7083
# Epoch 117/400
# 480/480 [==============================] - 0s 902us/sample - loss: 0.8452 - accuracy: 0.7167 - val_loss: 0.9679 - val_accuracy: 0.6250
# Epoch 118/400
# 480/480 [==============================] - 0s 897us/sample - loss: 0.8296 - accuracy: 0.7354 - val_loss: 0.8830 - val_accuracy: 0.7250
# Epoch 119/400
# 480/480 [==============================] - 0s 902us/sample - loss: 0.7687 - accuracy: 0.7542 - val_loss: 0.9177 - val_accuracy: 0.6833
# Epoch 120/400
# 480/480 [==============================] - 0s 867us/sample - loss: 0.7523 - accuracy: 0.7563 - val_loss: 0.9061 - val_accuracy: 0.7000
# Epoch 121/400
# 480/480 [==============================] - 0s 911us/sample - loss: 0.7709 - accuracy: 0.7542 - val_loss: 0.9252 - val_accuracy: 0.6750
# Epoch 122/400
# 480/480 [==============================] - 0s 975us/sample - loss: 0.7596 - accuracy: 0.7750 - val_loss: 0.9158 - val_accuracy: 0.7167
# Epoch 123/400
# 480/480 [==============================] - 0s 873us/sample - loss: 0.7133 - accuracy: 0.7667 - val_loss: 0.8713 - val_accuracy: 0.7250
# Epoch 124/400
# 480/480 [==============================] - 0s 978us/sample - loss: 0.7574 - accuracy: 0.7812 - val_loss: 0.9562 - val_accuracy: 0.7167
# Epoch 125/400
# 480/480 [==============================] - 0s 986us/sample - loss: 0.7538 - accuracy: 0.7500 - val_loss: 0.9115 - val_accuracy: 0.6750
# Epoch 126/400
# 480/480 [==============================] - 0s 935us/sample - loss: 0.7978 - accuracy: 0.7708 - val_loss: 0.9596 - val_accuracy: 0.6667
# Epoch 127/400
# 480/480 [==============================] - 0s 921us/sample - loss: 0.7831 - accuracy: 0.7500 - val_loss: 1.0182 - val_accuracy: 0.6667
# Epoch 128/400
# 480/480 [==============================] - 0s 880us/sample - loss: 0.7499 - accuracy: 0.7792 - val_loss: 0.9001 - val_accuracy: 0.6917
# Epoch 129/400
# 480/480 [==============================] - 0s 913us/sample - loss: 0.7704 - accuracy: 0.7500 - val_loss: 0.9035 - val_accuracy: 0.6917
# Se demoró: 58.50803804397583 segundos.

# %%
# Evaluar el modelo en el conjunto de prueba y obtener la pérdida y la precisión
loss, acc = model.evaluate(x_test, y_test, verbose=1)

# Imprimir la pérdida y la precisión
print("Loss:{0} - Accuracy:{1}".format(loss, acc))

# Guardar el mejor modelo en un archivo llamado "best_modelV1.h5"
save_model(model, "best_modelV1.h5")
# Out:
# 120/120 [==============================] - 0s 967us/sample - loss: 0.8377 - accuracy: 0.7500
# Loss:0.8376972198486328 - Accuracy:0.75

# %%
# Crear una figura con dos subplots
plt.figure(figsize=(15, 10))

# Subplot para graficar la precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')  # Precisión en entrenamiento
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Precisión en validación
plt.title('Accuracy Curve')  # Título del subplot
plt.xlabel('Epochs')  # Etiqueta del eje x
plt.ylabel('Accuracy')  # Etiqueta del eje y
plt.legend()  # Mostrar leyenda

# Subplot para graficar la pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')  # Pérdida en entrenamiento
plt.plot(history.history['val_loss'], label='Validation Loss')  # Pérdida en validación
plt.title('Loss Curve')  # Título del subplot
plt.xlabel('Epochs')  # Etiqueta del eje x
plt.ylabel('Loss')  # Etiqueta del eje y
plt.legend()  # Mostrar leyenda

# Mostrar las gráficas
plt.show()

# %%
# Realiza predicciones en el conjunto de prueba
y_pred = model.predict(x_test)

# Convierte las matrices codificadas one-hot a etiquetas de clase
y_test_labels = np.argmax(y_test, axis=1)
y_pred_labels = np.argmax(y_pred, axis=1)

# Define las etiquetas de clase correspondientes a tus clases
clases = ["Speed", "Stop", "Traffic-Light"]

# Calcula la matriz de confusión
confusion = confusion_matrix(y_test_labels, y_pred_labels, labels=range(len(clases)))

# Imprime el informe de clasificación que incluye precision, recall y f1-score por clase
print(classification_report(y_test_labels, y_pred_labels, target_names=clases))

print("------------------------------------------------------------------------------")

# Crea un gráfico de matriz de confusión
disp = ConfusionMatrixDisplay(confusion, display_labels=clases)
disp.plot()

# Mostrar las gráficas
plt.show()
# Out:
#                precision    recall  f1-score   support
#
#         Speed       0.68      0.68      0.68        40
#          Stop       0.91      0.80      0.85        40
# Traffic-Light       0.69      0.78      0.73        40
#
#      accuracy                           0.75       120
#     macro avg       0.76      0.75      0.75       120
#  weighted avg       0.76      0.75      0.75       120
#
# ------------------------------------------------------------------------------

# %%
# Subimos un nivel en el explorador de archivos
os.chdir("..")  # Cambia al directorio padre
os.chdir(f"{cwd}/model_test/")  # Nos movemos a la carpeta 'model_test' dentro del directorio padre
test_directory = os.getcwd()  # Guardamos la dirección actual en la variable 'test_directory'

# Imprime el directorio de trabajo actual después de los cambios
print(os.getcwd())
# Out:
# c:\Users\USER\Desktop\PDI\Traffic-Sign-Classifier\model_test

# %%
# Función para cargar y preprocesar una imagen
def convert_image(path):
    # Lee la imagen desde la ruta especificada
    img = cv2.imread(path)
    # Convierte la imagen de BGR (formato por defecto de OpenCV) a RGB
    img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Redimensiona la imagen a un tamaño específico (150x150 píxeles en este caso)
    resized_img = cv2.resize(img_color, (150, 150))
    # Normaliza los valores de píxeles de la imagen de 0 a 1
    normalized_img = resized_img / 255.0
    
    return normalized_img

# Función para darle la forma adecuada a la imagen para ser utilizada en el modelo
def reshape_image(img):
    # Reorganiza la imagen para que tenga la forma adecuada (1, 150, 150, 3)
    good_image = np.reshape(img, (1, 150, 150, 3))
    
    return good_image

# %%
# Lee las imágenes y las preprocesa utilizando la función 'convert_image'
image_Test_Speed = convert_image(f"{test_directory}/speed-1.jpg")
image_Test_Stop = convert_image(f"{test_directory}/stop-1.jpg")
image_Test_Traffic_Light = convert_image(f"{test_directory}/trafficlight-1.jpg")

# Crea una figura para mostrar las imágenes
plt.figure(figsize=(15, 10))

# Muestra las imágenes en subplots
plt.subplot(1, 3, 1), plt.imshow(image_Test_Speed)  # Subplot para la imagen de velocidad
plt.subplot(1, 3, 2), plt.imshow(image_Test_Stop)   # Subplot para la imagen de stop
plt.subplot(1, 3, 3), plt.imshow(image_Test_Traffic_Light)  # Subplot para la imagen de semáforo

# Mostrar las gráficas
plt.show()

# Da forma adecuada a las imágenes para ser procesadas por el modelo utilizando la función 'reshape_image'
image_Test_Speed = reshape_image(image_Test_Speed)
image_Test_Stop = reshape_image(image_Test_Stop)
image_Test_Traffic_Light = reshape_image(image_Test_Traffic_Light)

# %%
# Predicción para la imagen de velocidad
start = time.time()
y_pred_speed = model.predict(image_Test_Speed)
print("SPEED == 0")
# Imprime la clase predicha (0: Speed)
print("Predicción: ", y_pred_speed.argmax()) 
finish = time.time()
print(f"Speed se demoró: {finish - start} segundos.")
print("--------------------------------------------------------------------")

# Predicción para la imagen de stop
start = time.time()
print("STOP == 1")
y_pred_stop = model.predict(image_Test_Stop)
# Imprime la clase predicha (1: Stop)
print("Predicción: ", y_pred_stop.argmax())  
finish = time.time()
print(f"Stop se demoró: {finish - start} segundos.")
print("--------------------------------------------------------------------")

# Predicción para la imagen de semáforo
start = time.time()
print("TRAFFIC LIGHT == 2")
y_pred_trafficlight = model.predict(image_Test_Traffic_Light)
# Imprime la clase predicha (2: Traffic-Light)
print("Predicción: ", y_pred_trafficlight.argmax())  
finish = time.time()
print(f"Traffic Light se demoró: {finish - start} segundos.")
print("--------------------------------------------------------------------")
# Out:
# SPEED == 0
# Predicción:  0
# Speed se demoró: 0.015521049499511719 segundos.
# --------------------------------------------------------------------
# STOP == 1
# Predicción:  1
# Stop se demoró: 0.015028953552246094 segundos.
# --------------------------------------------------------------------
# TRAFFIC LIGHT == 2
# Predicción:  2
# Traffic Light se demoró: 0.016528606414794922 segundos.
# --------------------------------------------------------------------
